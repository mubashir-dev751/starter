# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mubashir-dev751/starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv('content_refresh_anonymized.csv')
print(f"Dataset shape: {df.shape}")
print("One row = One content item's 90-day performance window.")

columns_to_show = ['client_id', 'content_id', 'clicks_90d', 'ctr', 'avg_position', 'trend_pct']
display(df[columns_to_show].head())
# Out:
# Dataset shape: (30000, 44)
# One row = One content item's 90-day performance window.
#            client_id            content_id  clicks_90d   ctr  avg_position  \
# 0  client_f369cb89fc  content_304f48230142          29  0.76          10.6
# 1  client_4e07408562  content_a1fb4e703a9e           7  0.05          20.3
# 2  client_7f2253d7e2  content_9aa793d4d895          11  0.09          36.5
# 3  client_19581e27de  content_331d6c4de07b          58  0.49           6.2
# 4  client_3fdba35f04  content_d99b7a2d90ca          24  0.13          44.0
#
#    trend_pct
# 0      -41.4
# 1      -57.7
# 2      -60.9
# 3      -13.8
# 4      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
missing_rank = df[df['avg_position'] == 0].shape[0]
total_rows = df.shape[0]

print(f"Rows with no rank data (avg_position=0): {missing_rank} out of {total_rows} ({missing_rank/total_rows:.1%})")
print("A rigid rule relying on average position would instantly fail on these rows.")
# Out:
# Rows with no rank data (avg_position=0): 1205 out of 30000 (4.0%)
# A rigid rule relying on average position would instantly fail on these rows.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
